# %% [markdown]
# # 开始 AdaLoRA 训练

# %%
# AutoDL官方学术资源加速
import subprocess
import os

result = subprocess.run('bash -c "source /etc/network_turbo && env | grep proxy"', shell=True, capture_output=True, text=True)
output = result.stdout
for line in output.splitlines():
    if '=' in line:
        var, value = line.split('=', 1)
        os.environ[var] = value

# %%
import sys
import os

# 添加项目根目录到Python路径
project_root = "/home/cuipeng/Gemma"
sys.path.append(project_root)

# 现在可以正常导入src下的模块
from src.core.model.model_initializer import initialize_model_and_tokenizer
from src.core.utils.model_utils import generate_response, apply_chat_template

# %%
import os
import json
import torch # type: ignore
from transformers import ( # type: ignore
    AutoModelForCausalLM, 
    AutoTokenizer,
    TrainingArguments,
    Trainer,
    DataCollatorForLanguageModeling
)
from peft import AdaLoraConfig, get_peft_model # type: ignore
from datasets import Dataset # type: ignore
from transformers import BitsAndBytesConfig # type: ignore # 导入 BitsAndBytesConfig

# %%
def load_dataset(file_path, tokenizer):
    """加载数据集并进行预处理"""
    with open(file_path, 'r', encoding='utf-8') as f:
        data = json.load(f)
    
    # 使用tokenizer处理文本
    def preprocess_function(examples):
        return tokenizer(
            examples['text'],
            truncation=True, 
            max_length=512,
            padding='max_length',
            return_tensors=None
        )
    
    # 创建数据集
    dataset = Dataset.from_list([{
        'text': item['text'] # 直接使用text字段，不需要拼接prompt和completion
    } for item in data])
    
    # 对数据集进行预处理
    tokenized_dataset = dataset.map(
        preprocess_function,
        remove_columns=['text'],
        desc="正在对数据集进行分词处理",
    )
    
    return tokenized_dataset

# %%
def create_peft_config():
    """创建AdaLoRA配置"""
    return AdaLoraConfig(
        r=64,
        lora_alpha=32,
        target_modules=["q_proj", "k_proj", "v_proj", "o_proj"],
        lora_dropout=0.05,
        bias="none",
        task_type="CAUSAL_LM",
        inference_mode=False,
        target_r=32,
        beta1=0.85,
        beta2=0.85,
        tinit=500, # 预热
        tfinal=2000, # 最终步数
        deltaT=10, # 步数间隔
    )

# %%
# 2. 主训练函数
def train():
    # 设置模型路径和缓存目录
    model_path = "google/gemma-2-9b"
    cache_dir = "/root/autodl-tmp/gemma"
    lora_path = None

    print("创建模型和tokenizer...")
    model, tokenizer = initialize_model_and_tokenizer(
        model_path=model_path,
        cache_dir=cache_dir,
        lora_path=lora_path,
        use_quantization=True
    )
    
    # 然后加载和预处理数据集
    print("开始加载数据集...")
    train_dataset = load_dataset("../data_processing/stage1/data_final/train.json", tokenizer)
    eval_dataset = load_dataset("../data_processing/stage1/data_final/valid.json", tokenizer)
    
    print("应用AdaLoRA配置...")
    peft_config = create_peft_config()
    model = get_peft_model(model, peft_config)
    model.print_trainable_parameters() # trainable params: 13,420,512 || all params: 9,255,126,664 || trainable%: 0.1450
    
    # 创建训练参数
    training_args = TrainingArguments(
        output_dir="../../../../../../root/autodl-tmp/models/stage1/checkpoints/gemma-base-zh", # 保存中间模型和日志的目录
        learning_rate=5e-5, # 学习率
        num_train_epochs=5, # 训练轮数
        per_device_train_batch_size=2, # 训练批次大小
        per_device_eval_batch_size=4, # 选8好像也不会报错，选4放心一点  
        gradient_accumulation_steps=4, # 梯度累积步数 # 所以每个epoch的step总数: 80000 / (2*4) = 100000
        warmup_steps=500, # 预热步数, 在训练开始时逐渐增加学习率，以防止初始阶段的不稳定
        # max_steps=1000, # 最大训练步数, 训练的最大步数
        logging_steps=100, # 日志记录步数, 每100步记录一次日志
        save_steps=500, # 保存模型步数, 每500步保存一次模型
        evaluation_strategy="steps", # 按步数评估, 有三个选项: "no", "steps", "epoch"
        eval_steps=500, # 评估步数
        fp16=True, # 使用16位浮点数
        optim="paged_adamw_32bit", # 优化器
        lr_scheduler_type="cosine", # 学习率调度器类型
        report_to="tensorboard", # 报告到tensorboard
        remove_unused_columns=False, # 添加这一行
    )
    
    # 创建数据整理器
    data_collator = DataCollatorForLanguageModeling(
        tokenizer=tokenizer, 
        mlm=False, # 表示我们在做因果语言建模(CLM)而不是掩码语言建模(MLM)
    )
    # 没有这个组件，模型将无法正确处理不同长度的序列
    # 它确保了批处理中的数据格式统一
    # 对于语言模型训练来说是必需的组件
    
    # 创建训练器
    trainer = Trainer(
        model=model,
        args=training_args,
        train_dataset=train_dataset,
        eval_dataset=eval_dataset,
        data_collator=data_collator,
    )
    
    print("开始训练...")
    trainer.train()
    
    print("保存模型...")
    trainer.save_model("../../../../../../root/autodl-tmp/models/stage1/gemma-base-zh-final") # 保存最终模型

# %%
if __name__ == "__main__":
    train()
# Out:
# 创建模型和tokenizer...
# Loading checkpoint shards:   0%|          | 0/8 [00:00<?, ?it/s]
# 开始加载数据集...
# 正在对数据集进行分词处理:   0%|          | 0/80000 [00:00<?, ? examples/s]
# 正在对数据集进行分词处理:   0%|          | 0/1000 [00:00<?, ? examples/s]
# 应用AdaLoRA配置...
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/tuners/adalora/config.py:78: UserWarning: Note that `r` is not used in AdaLora and will be ignored.If you intended to set the initial rank, use `init_r` instead.
#   warnings.warn(
# trainable params: 13,420,512 || all params: 9,255,126,664 || trainable%: 0.1450
# 开始训练...
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/transformers/training_args.py:1575: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
#     <div>
#
#       <progress value='42836' max='50000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [42836/50000 27:46:21 < 4:38:41, 0.43 it/s, Epoch 4.28/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>9.096400</td>
#       <td>1.909219</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>5.922200</td>
#       <td>1.499785</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>5.638500</td>
#       <td>1.467625</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>5.706900</td>
#       <td>1.453999</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>5.632200</td>
#       <td>1.445326</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>5.584200</td>
#       <td>1.436898</td>
#     </tr>
#     <tr>
#       <td>3500</td>
#       <td>5.598100</td>
#       <td>1.431238</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>5.527600</td>
#       <td>1.425206</td>
#     </tr>
#     <tr>
#       <td>4500</td>
#       <td>5.544100</td>
#       <td>1.421027</td>
#     </tr>
#     <tr>
#       <td>5000</td>
#       <td>5.472400</td>
#       <td>1.416371</td>
#     </tr>
#     <tr>
#       <td>5500</td>
#       <td>5.591500</td>
#       <td>1.412687</td>
#     </tr>
#     <tr>
#       <td>6000</td>
#       <td>5.449300</td>
#       <td>1.409840</td>
#     </tr>
#     <tr>
#       <td>6500</td>
#       <td>5.431300</td>
#       <td>1.405868</td>
#     </tr>
#     <tr>
#       <td>7000</td>
#       <td>5.435000</td>
#       <td>1.403252</td>
#     </tr>
#     <tr>
#       <td>7500</td>
#       <td>5.472500</td>
#       <td>1.401325</td>
#     </tr>
#     <tr>
#       <td>8000</td>
#       <td>5.376000</td>
#       <td>1.397315</td>
#     </tr>
#     <tr>
#       <td>8500</td>
#       <td>5.416300</td>
#       <td>1.395720</td>
#     </tr>
#     <tr>
#       <td>9000</td>
#       <td>5.433400</td>
#       <td>1.393334</td>
#     </tr>
#     <tr>
#       <td>9500</td>
#       <td>5.429100</td>
#       <td>1.391576</td>
#     </tr>
#     <tr>
#       <td>10000</td>
#       <td>5.368600</td>
#       <td>1.389929</td>
#     </tr>
#     <tr>
#       <td>10500</td>
#       <td>5.433400</td>
#       <td>1.388549</td>
#     </tr>
#     <tr>
#       <td>11000</td>
#       <td>5.330200</td>
#       <td>1.386382</td>
#     </tr>
#     <tr>
#       <td>11500</td>
#       <td>5.399500</td>
#       <td>1.384867</td>
#     </tr>
#     <tr>
#       <td>12000</td>
#       <td>5.395200</td>
#       <td>1.383687</td>
#     </tr>
#     <tr>
#       <td>12500</td>
#       <td>5.333600</td>
#       <td>1.381630</td>
#     </tr>
#     <tr>
#       <td>13000</td>
#       <td>5.303800</td>
#       <td>1.381049</td>
#     </tr>
#     <tr>
#       <td>13500</td>
#       <td>5.337800</td>
#       <td>1.378694</td>
#     </tr>
#     <tr>
#       <td>14000</td>
#       <td>5.313000</td>
#       <td>1.378121</td>
#     </tr>
#     <tr>
#       <td>14500</td>
#       <td>5.393800</td>
#       <td>1.376976</td>
#     </tr>
#     <tr>
#       <td>15000</td>
#       <td>5.317600</td>
#       <td>1.375009</td>
#     </tr>
#     <tr>
#       <td>15500</td>
#       <td>5.300300</td>
#       <td>1.373677</td>
#     </tr>
#     <tr>
#       <td>16000</td>
#       <td>5.371700</td>
#       <td>1.373665</td>
#     </tr>
#     <tr>
#       <td>16500</td>
#       <td>5.346900</td>
#       <td>1.372030</td>
#     </tr>
#     <tr>
#       <td>17000</td>
#       <td>5.272800</td>
#       <td>1.371302</td>
#     </tr>
#     <tr>
#       <td>17500</td>
#       <td>5.298100</td>
#       <td>1.369422</td>
#     </tr>
#     <tr>
#       <td>18000</td>
#       <td>5.358500</td>
#       <td>1.368936</td>
#     </tr>
#     <tr>
#       <td>18500</td>
#       <td>5.258500</td>
#       <td>1.367460</td>
#     </tr>
#     <tr>
#       <td>19000</td>
#       <td>5.301500</td>
#       <td>1.366763</td>
#     </tr>
#     <tr>
#       <td>19500</td>
#       <td>5.379100</td>
#       <td>1.365632</td>
#     </tr>
#     <tr>
#       <td>20000</td>
#       <td>5.268300</td>
#       <td>1.364821</td>
#     </tr>
#     <tr>
#       <td>20500</td>
#       <td>5.254500</td>
#       <td>1.364169</td>
#     </tr>
#     <tr>
#       <td>21000</td>
#       <td>5.183400</td>
#       <td>1.363746</td>
#     </tr>
#     <tr>
#       <td>21500</td>
#       <td>5.348200</td>
#       <td>1.362666</td>
#     </tr>
#     <tr>
#       <td>22000</td>
#       <td>5.297400</td>
#       <td>1.362564</td>
#     </tr>
#     <tr>
#       <td>22500</td>
#       <td>5.309400</td>
#       <td>1.361612</td>
#     </tr>
#     <tr>
#       <td>23000</td>
#       <td>5.275400</td>
#       <td>1.360395</td>
#     </tr>
#     <tr>
#       <td>23500</td>
#       <td>5.261400</td>
#       <td>1.359979</td>
#     </tr>
#     <tr>
#       <td>24000</td>
#       <td>5.257800</td>
#       <td>1.359338</td>
#     </tr>
#     <tr>
#       <td>24500</td>
#       <td>5.163300</td>
#       <td>1.358602</td>
#     </tr>
#     <tr>
#       <td>25000</td>
#       <td>5.283400</td>
#       <td>1.358073</td>
#     </tr>
#     <tr>
#       <td>25500</td>
#       <td>5.114900</td>
#       <td>1.357895</td>
#     </tr>
#     <tr>
#       <td>26000</td>
#       <td>5.199200</td>
#       <td>1.357026</td>
#     </tr>
#     <tr>
#       <td>26500</td>
#       <td>5.273900</td>
#       <td>1.356536</td>
#     </tr>
#     <tr>
#       <td>27000</td>
#       <td>5.296200</td>
#       <td>1.355522</td>
#     </tr>
#     <tr>
#       <td>27500</td>
#       <td>5.228900</td>
#       <td>1.355195</td>
#     </tr>
#     <tr>
#       <td>28000</td>
#       <td>5.192100</td>
#       <td>1.355008</td>
#     </tr>
#     <tr>
#       <td>28500</td>
#       <td>5.236900</td>
#       <td>1.354455</td>
#     </tr>
#     <tr>
#       <td>29000</td>
#       <td>5.310000</td>
#       <td>1.354030</td>
#     </tr>
#     <tr>
#       <td>29500</td>
#       <td>5.238100</td>
#       <td>1.352957</td>
#     </tr>
#     <tr>
#       <td>30000</td>
#       <td>5.134500</td>
#       <td>1.352917</td>
#     </tr>
#     <tr>
#       <td>30500</td>
#       <td>5.224300</td>
#       <td>1.352211</td>
#     </tr>
#     <tr>
#       <td>31000</td>
#       <td>5.282400</td>
#       <td>1.351483</td>
#     </tr>
#     <tr>
#       <td>31500</td>
#       <td>5.126300</td>
#       <td>1.351705</td>
#     </tr>
#     <tr>
#       <td>32000</td>
#       <td>5.149800</td>
#       <td>1.351753</td>
#     </tr>
#     <tr>
#       <td>32500</td>
#       <td>5.208700</td>
#       <td>1.351658</td>
#     </tr>
#     <tr>
#       <td>33000</td>
#       <td>5.158000</td>
#       <td>1.351643</td>
#     </tr>
#     <tr>
#       <td>33500</td>
#       <td>5.268200</td>
#       <td>1.350775</td>
#     </tr>
#     <tr>
#       <td>34000</td>
#       <td>5.122300</td>
#       <td>1.350562</td>
#     </tr>
#     <tr>
#       <td>34500</td>
#       <td>5.259700</td>
#       <td>1.349702</td>
#     </tr>
#     <tr>
#       <td>35000</td>
#       <td>5.246600</td>
#       <td>1.349775</td>
#     </tr>
#     <tr>
#       <td>35500</td>
#       <td>5.115600</td>
#       <td>1.349550</td>
#     </tr>
#     <tr>
#       <td>36000</td>
#       <td>5.166700</td>
#       <td>1.349542</td>
#     </tr>
#     <tr>
#       <td>36500</td>
#       <td>5.295600</td>
#       <td>1.348992</td>
#     </tr>
#     <tr>
#       <td>37000</td>
#       <td>5.269700</td>
#       <td>1.348667</td>
#     </tr>
#     <tr>
#       <td>37500</td>
#       <td>5.115100</td>
#       <td>1.348538</td>
#     </tr>
#     <tr>
#       <td>38000</td>
#       <td>5.155500</td>
#       <td>1.348362</td>
#     </tr>
#     <tr>
#       <td>38500</td>
#       <td>5.168800</td>
#       <td>1.347955</td>
#     </tr>
#     <tr>
#       <td>39000</td>
#       <td>5.217800</td>
#       <td>1.347663</td>
#     </tr>
#     <tr>
#       <td>39500</td>
#       <td>5.259700</td>
#       <td>1.347272</td>
#     </tr>
#     <tr>
#       <td>40000</td>
#       <td>5.191400</td>
#       <td>1.347146</td>
#     </tr>
#     <tr>
#       <td>40500</td>
#       <td>5.160600</td>
#       <td>1.347165</td>
#     </tr>
#     <tr>
#       <td>41000</td>
#       <td>5.317400</td>
#       <td>1.347122</td>
#     </tr>
#     <tr>
#       <td>41500</td>
#       <td>5.168800</td>
#       <td>1.347127</td>
#     </tr>
#     <tr>
#       <td>42000</td>
#       <td>5.069300</td>
#       <td>1.347266</td>
#     </tr>
#     <tr>
#       <td>42500</td>
#       <td>5.210100</td>
#       <td>1.346964</td>
#     </tr>
#   </tbody>
# </table><p>
# The 'batch_size' argument of HybridCache is deprecated and will be removed in v4.49. Use the more precisely named 'max_batch_size' argument instead.
# The 'batch_size' attribute of HybridCache is deprecated and will be removed in v4.49. Use the more precisely named 'self.max_batch_size' attribute instead.
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/other.py:716: UserWarning: Unable to fetch remote file due to the following error 401 Client Error. (Request ID: Root=1-67600cce-67f7cdd74c61cb670199fc3a;c7c385f6-42ee-46cf-b756-b5623a5221ef)
#
# Cannot access gated repo for url https://huggingface.co/google/gemma-2-9b/resolve/main/config.json.
# Access to model google/gemma-2-9b is restricted. You must have access to it and be authenticated to access it. Please log in. - silently ignoring the lookup for the file config.json in google/gemma-2-9b.
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/save_and_load.py:246: UserWarning: Could not find a config file in google/gemma-2-9b - will assume that the vocabulary was not modified.
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/other.py:716: UserWarning: Unable to fetch remote file due to the following error 401 Client Error. (Request ID: Root=1-6760115c-378579b37a3569e4333f8fe0;ad8b3198-738a-499f-86f6-3a91e0f5b6f4)
#
# Cannot access gated repo for url https://huggingface.co/google/gemma-2-9b/resolve/main/config.json.
# Access to model google/gemma-2-9b is restricted. You must have access to it and be authenticated to access it. Please log in. - silently ignoring the lookup for the file config.json in google/gemma-2-9b.
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/save_and_load.py:246: UserWarning: Could not find a config file in google/gemma-2-9b - will assume that the vocabulary was not modified.
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/other.py:716: UserWarning: Unable to fetch remote file due to the following error 401 Client Error. (Request ID: Root=1-676015e9-00f319d9281a5b765cc1d80b;eb1b7c62-a760-4005-9810-af1ecf876dc8)
#
# Cannot access gated repo for url https://huggingface.co/google/gemma-2-9b/resolve/main/config.json.
# Access to model google/gemma-2-9b is restricted. You must have access to it and be authenticated to access it. Please log in. - silently ignoring the lookup for the file config.json in google/gemma-2-9b.
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/save_and_load.py:246: UserWarning: Could not find a config file in google/gemma-2-9b - will assume that the vocabulary was not modified.
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/other.py:716: UserWarning: Unable to fetch remote file due to the following error 401 Client Error. (Request ID: Root=1-67601a72-3d621609175f55504f9080b3;8f9265dd-42a8-44af-aebc-321983c32e4e)
#
# Cannot access gated repo for url https://huggingface.co/google/gemma-2-9b/resolve/main/config.json.
# Access to model google/gemma-2-9b is restricted. You must have access to it and be authenticated to access it. Please log in. - silently ignoring the lookup for the file config.json in google/gemma-2-9b.
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/save_and_load.py:246: UserWarning: Could not find a config file in google/gemma-2-9b - will assume that the vocabulary was not modified.
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/other.py:716: UserWarning: Unable to fetch remote file due to the following error 401 Client Error. (Request ID: Root=1-67601efb-2417de5e62aa714d2f74063c;178fc88b-4484-4c86-936a-e8a6d19a7229)
#
# Cannot access gated repo for url https://huggingface.co/google/gemma-2-9b/resolve/main/config.json.
# Access to model google/gemma-2-9b is restricted. You must have access to it and be authenticated to access it. Please log in. - silently ignoring the lookup for the file config.json in google/gemma-2-9b.
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/save_and_load.py:246: UserWarning: Could not find a config file in google/gemma-2-9b - will assume that the vocabulary was not modified.
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/other.py:716: UserWarning: Unable to fetch remote file due to the following error 401 Client Error. (Request ID: Root=1-67602385-261d43392cec106619a70734;a84a2170-b2d0-46df-96f6-465b66964292)
#
# Cannot access gated repo for url https://huggingface.co/google/gemma-2-9b/resolve/main/config.json.
# Access to model google/gemma-2-9b is restricted. You must have access to it and be authenticated to access it. Please log in. - silently ignoring the lookup for the file config.json in google/gemma-2-9b.
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/save_and_load.py:246: UserWarning: Could not find a config file in google/gemma-2-9b - will assume that the vocabulary was not modified.
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/other.py:716: UserWarning: Unable to fetch remote file due to the following error 401 Client Error. (Request ID: Root=1-67602809-5054d2e92500d2b052a01a75;791cf069-5c33-4691-b5de-d398a9748049)
#
# Cannot access gated repo for url https://huggingface.co/google/gemma-2-9b/resolve/main/config.json.
# Access to model google/gemma-2-9b is restricted. You must have access to it and be authenticated to access it. Please log in. - silently ignoring the lookup for the file config.json in google/gemma-2-9b.
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/save_and_load.py:246: UserWarning: Could not find a config file in google/gemma-2-9b - will assume that the vocabulary was not modified.
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/other.py:716: UserWarning: Unable to fetch remote file due to the following error 401 Client Error. (Request ID: Root=1-67602c92-5d0ebfa834593889256d2abd;5cee4d20-3785-463a-bba7-436e0f7d2b46)
#
# Cannot access gated repo for url https://huggingface.co/google/gemma-2-9b/resolve/main/config.json.
# Access to model google/gemma-2-9b is restricted. You must have access to it and be authenticated to access it. Please log in. - silently ignoring the lookup for the file config.json in google/gemma-2-9b.
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/save_and_load.py:246: UserWarning: Could not find a config file in google/gemma-2-9b - will assume that the vocabulary was not modified.
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/other.py:716: UserWarning: Unable to fetch remote file due to the following error 401 Client Error. (Request ID: Root=1-6760311b-363b64bb3d626ae622631098;fd75bd11-7025-4d83-a8cf-4a68451c4f7e)
#
# Cannot access gated repo for url https://huggingface.co/google/gemma-2-9b/resolve/main/config.json.
# Access to model google/gemma-2-9b is restricted. You must have access to it and be authenticated to access it. Please log in. - silently ignoring the lookup for the file config.json in google/gemma-2-9b.
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/save_and_load.py:246: UserWarning: Could not find a config file in google/gemma-2-9b - will assume that the vocabulary was not modified.
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/other.py:716: UserWarning: Unable to fetch remote file due to the following error 401 Client Error. (Request ID: Root=1-676035a4-6846f24a15796d3a33fbe5c4;ab56c757-9da2-4576-a341-dfe21db105a3)
#
# Cannot access gated repo for url https://huggingface.co/google/gemma-2-9b/resolve/main/config.json.
# Access to model google/gemma-2-9b is restricted. You must have access to it and be authenticated to access it. Please log in. - silently ignoring the lookup for the file config.json in google/gemma-2-9b.
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/save_and_load.py:246: UserWarning: Could not find a config file in google/gemma-2-9b - will assume that the vocabulary was not modified.
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/other.py:716: UserWarning: Unable to fetch remote file due to the following error 401 Client Error. (Request ID: Root=1-67603a2f-1ab8cea5623bd99f0cdc6f12;3a0778e7-6b74-4bb7-8083-7f4087e0f3d2)
#
# Cannot access gated repo for url https://huggingface.co/google/gemma-2-9b/resolve/main/config.json.
# Access to model google/gemma-2-9b is restricted. You must have access to it and be authenticated to access it. Please log in. - silently ignoring the lookup for the file config.json in google/gemma-2-9b.
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/save_and_load.py:246: UserWarning: Could not find a config file in google/gemma-2-9b - will assume that the vocabulary was not modified.
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/other.py:716: UserWarning: Unable to fetch remote file due to the following error 401 Client Error. (Request ID: Root=1-67603eb7-0c3aa72208d6fac04f4b3575;7472d613-5eed-4d15-bb10-ba83ef8f5be2)
#
# Cannot access gated repo for url https://huggingface.co/google/gemma-2-9b/resolve/main/config.json.
# Access to model google/gemma-2-9b is restricted. You must have access to it and be authenticated to access it. Please log in. - silently ignoring the lookup for the file config.json in google/gemma-2-9b.
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/save_and_load.py:246: UserWarning: Could not find a config file in google/gemma-2-9b - will assume that the vocabulary was not modified.
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/other.py:716: UserWarning: Unable to fetch remote file due to the following error 401 Client Error. (Request ID: Root=1-6760433d-5c4b1863666d14d8498d1b02;d3dbacae-57c1-4616-8ce8-8f143a51ccab)
#
# Cannot access gated repo for url https://huggingface.co/google/gemma-2-9b/resolve/main/config.json.
# Access to model google/gemma-2-9b is restricted. You must have access to it and be authenticated to access it. Please log in. - silently ignoring the lookup for the file config.json in google/gemma-2-9b.
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/save_and_load.py:246: UserWarning: Could not find a config file in google/gemma-2-9b - will assume that the vocabulary was not modified.
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/other.py:716: UserWarning: Unable to fetch remote file due to the following error 401 Client Error. (Request ID: Root=1-676047c3-098ea8971cf1a6ac196b6378;b4449ddf-435e-4eaa-9d3d-a18b1a3cb70f)
#
# Cannot access gated repo for url https://huggingface.co/google/gemma-2-9b/resolve/main/config.json.
# Access to model google/gemma-2-9b is restricted. You must have access to it and be authenticated to access it. Please log in. - silently ignoring the lookup for the file config.json in google/gemma-2-9b.
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/save_and_load.py:246: UserWarning: Could not find a config file in google/gemma-2-9b - will assume that the vocabulary was not modified.
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/other.py:716: UserWarning: Unable to fetch remote file due to the following error 401 Client Error. (Request ID: Root=1-67604c48-1d3c77c43b492ce9503d7622;a6f873ed-1c80-4135-a7c4-9ab58f97fd64)
#
# Cannot access gated repo for url https://huggingface.co/google/gemma-2-9b/resolve/main/config.json.
# Access to model google/gemma-2-9b is restricted. You must have access to it and be authenticated to access it. Please log in. - silently ignoring the lookup for the file config.json in google/gemma-2-9b.
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/save_and_load.py:246: UserWarning: Could not find a config file in google/gemma-2-9b - will assume that the vocabulary was not modified.
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/other.py:716: UserWarning: Unable to fetch remote file due to the following error 401 Client Error. (Request ID: Root=1-676050ce-60b805cf488f351640b96836;98902436-aaf5-45c5-9c94-987e64775d8f)
#
# Cannot access gated repo for url https://huggingface.co/google/gemma-2-9b/resolve/main/config.json.
# Access to model google/gemma-2-9b is restricted. You must have access to it and be authenticated to access it. Please log in. - silently ignoring the lookup for the file config.json in google/gemma-2-9b.
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/save_and_load.py:246: UserWarning: Could not find a config file in google/gemma-2-9b - will assume that the vocabulary was not modified.
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/other.py:716: UserWarning: Unable to fetch remote file due to the following error 401 Client Error. (Request ID: Root=1-67605554-744d4ae15c267b840179a84e;a5eedeac-ba3b-444c-a232-567e93d7e730)
#
# Cannot access gated repo for url https://huggingface.co/google/gemma-2-9b/resolve/main/config.json.
# Access to model google/gemma-2-9b is restricted. You must have access to it and be authenticated to access it. Please log in. - silently ignoring the lookup for the file config.json in google/gemma-2-9b.
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/save_and_load.py:246: UserWarning: Could not find a config file in google/gemma-2-9b - will assume that the vocabulary was not modified.
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/other.py:716: UserWarning: Unable to fetch remote file due to the following error 401 Client Error. (Request ID: Root=1-676059d7-34a58687026c1743483aca22;823cd36e-df77-41b8-959a-f5b925364782)
#
# Cannot access gated repo for url https://huggingface.co/google/gemma-2-9b/resolve/main/config.json.
# Access to model google/gemma-2-9b is restricted. You must have access to it and be authenticated to access it. Please log in. - silently ignoring the lookup for the file config.json in google/gemma-2-9b.
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/save_and_load.py:246: UserWarning: Could not find a config file in google/gemma-2-9b - will assume that the vocabulary was not modified.
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/other.py:716: UserWarning: Unable to fetch remote file due to the following error 401 Client Error. (Request ID: Root=1-67605e5d-5a4b0d4f2658dcd2336fc075;46f87c96-d50e-4651-8289-97a3bb7c93d8)
#
# Cannot access gated repo for url https://huggingface.co/google/gemma-2-9b/resolve/main/config.json.
# Access to model google/gemma-2-9b is restricted. You must have access to it and be authenticated to access it. Please log in. - silently ignoring the lookup for the file config.json in google/gemma-2-9b.
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/save_and_load.py:246: UserWarning: Could not find a config file in google/gemma-2-9b - will assume that the vocabulary was not modified.
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/other.py:716: UserWarning: Unable to fetch remote file due to the following error 401 Client Error. (Request ID: Root=1-676062e4-64c327d462f1c0ed08aa0577;78f0bfb6-19da-48fe-bc45-c3dd95a22643)
#
# Cannot access gated repo for url https://huggingface.co/google/gemma-2-9b/resolve/main/config.json.
# Access to model google/gemma-2-9b is restricted. You must have access to it and be authenticated to access it. Please log in. - silently ignoring the lookup for the file config.json in google/gemma-2-9b.
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/save_and_load.py:246: UserWarning: Could not find a config file in google/gemma-2-9b - will assume that the vocabulary was not modified.
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/other.py:716: UserWarning: Unable to fetch remote file due to the following error (ReadTimeoutError("HTTPSConnectionPool(host='huggingface.co', port=443): Read timed out. (read timeout=10)"), '(Request ID: 5db1a6a3-ac3c-4645-875b-f14ff7d8e0cf)') - silently ignoring the lookup for the file config.json in google/gemma-2-9b.
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/save_and_load.py:246: UserWarning: Could not find a config file in google/gemma-2-9b - will assume that the vocabulary was not modified.
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/other.py:716: UserWarning: Unable to fetch remote file due to the following error 401 Client Error. (Request ID: Root=1-67606bfc-6cb5cc4f230670574f86574f;942e50ba-23ab-4b2b-b6d9-712786b2b3f3)
#
# Cannot access gated repo for url https://huggingface.co/google/gemma-2-9b/resolve/main/config.json.
# Access to model google/gemma-2-9b is restricted. You must have access to it and be authenticated to access it. Please log in. - silently ignoring the lookup for the file config.json in google/gemma-2-9b.
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/save_and_load.py:246: UserWarning: Could not find a config file in google/gemma-2-9b - will assume that the vocabulary was not modified.
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/other.py:716: UserWarning: Unable to fetch remote file due to the following error 401 Client Error. (Request ID: Root=1-67607082-7f2db1426dd661b634c3588a;66ba3801-21f6-42aa-a6e0-342085fc4381)
#
# Cannot access gated repo for url https://huggingface.co/google/gemma-2-9b/resolve/main/config.json.
# Access to model google/gemma-2-9b is restricted. You must have access to it and be authenticated to access it. Please log in. - silently ignoring the lookup for the file config.json in google/gemma-2-9b.
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/save_and_load.py:246: UserWarning: Could not find a config file in google/gemma-2-9b - will assume that the vocabulary was not modified.
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/other.py:716: UserWarning: Unable to fetch remote file due to the following error 401 Client Error. (Request ID: Root=1-67607508-472e3ffe527ed7b427580f51;9bda4fc9-5891-4361-8120-0790e4f09f9d)
#
# Cannot access gated repo for url https://huggingface.co/google/gemma-2-9b/resolve/main/config.json.
# Access to model google/gemma-2-9b is restricted. You must have access to it and be authenticated to access it. Please log in. - silently ignoring the lookup for the file config.json in google/gemma-2-9b.
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/save_and_load.py:246: UserWarning: Could not find a config file in google/gemma-2-9b - will assume that the vocabulary was not modified.
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/other.py:716: UserWarning: Unable to fetch remote file due to the following error 401 Client Error. (Request ID: Root=1-6760798f-633135ef196fd0962eeba1aa;a2d333bf-6469-4565-8cdb-adf6a220f258)
#
# Cannot access gated repo for url https://huggingface.co/google/gemma-2-9b/resolve/main/config.json.
# Access to model google/gemma-2-9b is restricted. You must have access to it and be authenticated to access it. Please log in. - silently ignoring the lookup for the file config.json in google/gemma-2-9b.
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/save_and_load.py:246: UserWarning: Could not find a config file in google/gemma-2-9b - will assume that the vocabulary was not modified.
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/other.py:716: UserWarning: Unable to fetch remote file due to the following error 401 Client Error. (Request ID: Root=1-67607e17-76a1973e0941c7c40be1d4f2;3b797319-4d2e-4e51-8631-619e1df58155)
#
# Cannot access gated repo for url https://huggingface.co/google/gemma-2-9b/resolve/main/config.json.
# Access to model google/gemma-2-9b is restricted. You must have access to it and be authenticated to access it. Please log in. - silently ignoring the lookup for the file config.json in google/gemma-2-9b.
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/save_and_load.py:246: UserWarning: Could not find a config file in google/gemma-2-9b - will assume that the vocabulary was not modified.
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/other.py:716: UserWarning: Unable to fetch remote file due to the following error 401 Client Error. (Request ID: Root=1-6760829e-712fe1a0786b60705430cf8e;a3184776-257f-4988-94f0-37663dee2b53)
#
# Cannot access gated repo for url https://huggingface.co/google/gemma-2-9b/resolve/main/config.json.
# Access to model google/gemma-2-9b is restricted. You must have access to it and be authenticated to access it. Please log in. - silently ignoring the lookup for the file config.json in google/gemma-2-9b.
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/save_and_load.py:246: UserWarning: Could not find a config file in google/gemma-2-9b - will assume that the vocabulary was not modified.
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/other.py:716: UserWarning: Unable to fetch remote file due to the following error 401 Client Error. (Request ID: Root=1-67608726-08634c5710003ce22cff74a1;d8a83f2f-06f4-41f5-8d83-e213f0e00751)
#
# Cannot access gated repo for url https://huggingface.co/google/gemma-2-9b/resolve/main/config.json.
# Access to model google/gemma-2-9b is restricted. You must have access to it and be authenticated to access it. Please log in. - silently ignoring the lookup for the file config.json in google/gemma-2-9b.
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/save_and_load.py:246: UserWarning: Could not find a config file in google/gemma-2-9b - will assume that the vocabulary was not modified.
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/other.py:716: UserWarning: Unable to fetch remote file due to the following error 401 Client Error. (Request ID: Root=1-67608bae-610ea208273633d23cbc3e2e;8e116150-b28d-45eb-a00a-33b158f443c4)
#
# Cannot access gated repo for url https://huggingface.co/google/gemma-2-9b/resolve/main/config.json.
# Access to model google/gemma-2-9b is restricted. You must have access to it and be authenticated to access it. Please log in. - silently ignoring the lookup for the file config.json in google/gemma-2-9b.
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/save_and_load.py:246: UserWarning: Could not find a config file in google/gemma-2-9b - will assume that the vocabulary was not modified.
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/other.py:716: UserWarning: Unable to fetch remote file due to the following error 401 Client Error. (Request ID: Root=1-67609037-5a9e7a7653a790625b2fca41;bc36e8f3-f157-4de5-9ead-368fde3f4765)
#
# Cannot access gated repo for url https://huggingface.co/google/gemma-2-9b/resolve/main/config.json.
# Access to model google/gemma-2-9b is restricted. You must have access to it and be authenticated to access it. Please log in. - silently ignoring the lookup for the file config.json in google/gemma-2-9b.
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/save_and_load.py:246: UserWarning: Could not find a config file in google/gemma-2-9b - will assume that the vocabulary was not modified.
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/other.py:716: UserWarning: Unable to fetch remote file due to the following error 401 Client Error. (Request ID: Root=1-676094c0-49f25e887ee5553d46f9ab72;1e1a4ba9-bf44-4e00-aa14-4221193eddc3)
#
# Cannot access gated repo for url https://huggingface.co/google/gemma-2-9b/resolve/main/config.json.
# Access to model google/gemma-2-9b is restricted. You must have access to it and be authenticated to access it. Please log in. - silently ignoring the lookup for the file config.json in google/gemma-2-9b.
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/save_and_load.py:246: UserWarning: Could not find a config file in google/gemma-2-9b - will assume that the vocabulary was not modified.
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/other.py:716: UserWarning: Unable to fetch remote file due to the following error 401 Client Error. (Request ID: Root=1-67609947-381157675a5c83594e1bc55b;2c88d445-3b36-4045-9289-72c1daf243ff)
#
# Cannot access gated repo for url https://huggingface.co/google/gemma-2-9b/resolve/main/config.json.
# Access to model google/gemma-2-9b is restricted. You must have access to it and be authenticated to access it. Please log in. - silently ignoring the lookup for the file config.json in google/gemma-2-9b.
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/save_and_load.py:246: UserWarning: Could not find a config file in google/gemma-2-9b - will assume that the vocabulary was not modified.
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/other.py:716: UserWarning: Unable to fetch remote file due to the following error 401 Client Error. (Request ID: Root=1-67609dce-6d8323bc0412d0411bf1975a;a605b963-fa29-49b5-9f08-3557698b026c)
#
# Cannot access gated repo for url https://huggingface.co/google/gemma-2-9b/resolve/main/config.json.
# Access to model google/gemma-2-9b is restricted. You must have access to it and be authenticated to access it. Please log in. - silently ignoring the lookup for the file config.json in google/gemma-2-9b.
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/save_and_load.py:246: UserWarning: Could not find a config file in google/gemma-2-9b - will assume that the vocabulary was not modified.
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/other.py:716: UserWarning: Unable to fetch remote file due to the following error 401 Client Error. (Request ID: Root=1-6760a255-287a634b1cae37d71d409a67;ad062d50-ebac-4a29-91d8-a41afb4ee4e4)
#
# Cannot access gated repo for url https://huggingface.co/google/gemma-2-9b/resolve/main/config.json.
# Access to model google/gemma-2-9b is restricted. You must have access to it and be authenticated to access it. Please log in. - silently ignoring the lookup for the file config.json in google/gemma-2-9b.
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/save_and_load.py:246: UserWarning: Could not find a config file in google/gemma-2-9b - will assume that the vocabulary was not modified.
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/other.py:716: UserWarning: Unable to fetch remote file due to the following error 401 Client Error. (Request ID: Root=1-6760a6dc-4918fe49038c6a50536a3965;b87d58b3-372e-4ee1-b318-8a135c4b4553)
#
# Cannot access gated repo for url https://huggingface.co/google/gemma-2-9b/resolve/main/config.json.
# Access to model google/gemma-2-9b is restricted. You must have access to it and be authenticated to access it. Please log in. - silently ignoring the lookup for the file config.json in google/gemma-2-9b.
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/save_and_load.py:246: UserWarning: Could not find a config file in google/gemma-2-9b - will assume that the vocabulary was not modified.
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/other.py:716: UserWarning: Unable to fetch remote file due to the following error 401 Client Error. (Request ID: Root=1-6760ab63-7720280728683cf123b943ed;d3d5549a-ad8a-4c83-a594-89aa0d201f95)
#
# Cannot access gated repo for url https://huggingface.co/google/gemma-2-9b/resolve/main/config.json.
# Access to model google/gemma-2-9b is restricted. You must have access to it and be authenticated to access it. Please log in. - silently ignoring the lookup for the file config.json in google/gemma-2-9b.
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/save_and_load.py:246: UserWarning: Could not find a config file in google/gemma-2-9b - will assume that the vocabulary was not modified.
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/other.py:716: UserWarning: Unable to fetch remote file due to the following error 401 Client Error. (Request ID: Root=1-6760afea-326c86a86f2f91572675f4af;f68474f2-78a3-4221-bc24-ad91450dc13a)
#
# Cannot access gated repo for url https://huggingface.co/google/gemma-2-9b/resolve/main/config.json.
# Access to model google/gemma-2-9b is restricted. You must have access to it and be authenticated to access it. Please log in. - silently ignoring the lookup for the file config.json in google/gemma-2-9b.
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/save_and_load.py:246: UserWarning: Could not find a config file in google/gemma-2-9b - will assume that the vocabulary was not modified.
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/other.py:716: UserWarning: Unable to fetch remote file due to the following error 401 Client Error. (Request ID: Root=1-6760b473-16eb64ac34afc87707528b17;fa11ae10-1508-490a-b514-3d1318163ef4)
#
# Cannot access gated repo for url https://huggingface.co/google/gemma-2-9b/resolve/main/config.json.
# Access to model google/gemma-2-9b is restricted. You must have access to it and be authenticated to access it. Please log in. - silently ignoring the lookup for the file config.json in google/gemma-2-9b.
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/save_and_load.py:246: UserWarning: Could not find a config file in google/gemma-2-9b - will assume that the vocabulary was not modified.
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/other.py:716: UserWarning: Unable to fetch remote file due to the following error 401 Client Error. (Request ID: Root=1-6760b8f9-4e242e6b527bcc0710ee3853;fa8a994c-d9c0-4ae5-af53-2286b7bfd6b5)
#
# Cannot access gated repo for url https://huggingface.co/google/gemma-2-9b/resolve/main/config.json.
# Access to model google/gemma-2-9b is restricted. You must have access to it and be authenticated to access it. Please log in. - silently ignoring the lookup for the file config.json in google/gemma-2-9b.
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/save_and_load.py:246: UserWarning: Could not find a config file in google/gemma-2-9b - will assume that the vocabulary was not modified.
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/other.py:716: UserWarning: Unable to fetch remote file due to the following error 401 Client Error. (Request ID: Root=1-6760bd8c-7d39888d5fa630c5241e3853;3909f13f-4a43-4ab0-bc24-acfbf7569029)
#
# Cannot access gated repo for url https://huggingface.co/google/gemma-2-9b/resolve/main/config.json.
# Access to model google/gemma-2-9b is restricted. You must have access to it and be authenticated to access it. Please log in. - silently ignoring the lookup for the file config.json in google/gemma-2-9b.
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/save_and_load.py:246: UserWarning: Could not find a config file in google/gemma-2-9b - will assume that the vocabulary was not modified.
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/other.py:716: UserWarning: Unable to fetch remote file due to the following error 401 Client Error. (Request ID: Root=1-6760c213-426fce036f8dd76f593f3c8a;8ad663ee-bed4-4ccd-9727-ac93b60d2357)
#
# Cannot access gated repo for url https://huggingface.co/google/gemma-2-9b/resolve/main/config.json.
# Access to model google/gemma-2-9b is restricted. You must have access to it and be authenticated to access it. Please log in. - silently ignoring the lookup for the file config.json in google/gemma-2-9b.
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/save_and_load.py:246: UserWarning: Could not find a config file in google/gemma-2-9b - will assume that the vocabulary was not modified.
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/other.py:716: UserWarning: Unable to fetch remote file due to the following error 401 Client Error. (Request ID: Root=1-6760c69c-4749390119dea4f31fbaae19;4b5ad918-a9f0-47e8-aa23-cff7ec0f7e22)
#
# Cannot access gated repo for url https://huggingface.co/google/gemma-2-9b/resolve/main/config.json.
# Access to model google/gemma-2-9b is restricted. You must have access to it and be authenticated to access it. Please log in. - silently ignoring the lookup for the file config.json in google/gemma-2-9b.
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/save_and_load.py:246: UserWarning: Could not find a config file in google/gemma-2-9b - will assume that the vocabulary was not modified.
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/other.py:716: UserWarning: Unable to fetch remote file due to the following error 401 Client Error. (Request ID: Root=1-6760cb27-64140d75785c14035ff1f2b4;826ffcdd-c72b-4092-9dd4-b6463d8be55a)
#
# Cannot access gated repo for url https://huggingface.co/google/gemma-2-9b/resolve/main/config.json.
# Access to model google/gemma-2-9b is restricted. You must have access to it and be authenticated to access it. Please log in. - silently ignoring the lookup for the file config.json in google/gemma-2-9b.
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/save_and_load.py:246: UserWarning: Could not find a config file in google/gemma-2-9b - will assume that the vocabulary was not modified.
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/other.py:716: UserWarning: Unable to fetch remote file due to the following error 401 Client Error. (Request ID: Root=1-6760cfb3-525f338164486d233443e4b9;4a789478-8f7a-44b0-98df-d148d26a2e43)
#
# Cannot access gated repo for url https://huggingface.co/google/gemma-2-9b/resolve/main/config.json.
# Access to model google/gemma-2-9b is restricted. You must have access to it and be authenticated to access it. Please log in. - silently ignoring the lookup for the file config.json in google/gemma-2-9b.
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/save_and_load.py:246: UserWarning: Could not find a config file in google/gemma-2-9b - will assume that the vocabulary was not modified.
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/other.py:716: UserWarning: Unable to fetch remote file due to the following error 401 Client Error. (Request ID: Root=1-6760d443-46cc6ce41c92b3b21f066f9f;e3505bf3-12ce-4301-936a-8dff96953cfc)
#
# Cannot access gated repo for url https://huggingface.co/google/gemma-2-9b/resolve/main/config.json.
# Access to model google/gemma-2-9b is restricted. You must have access to it and be authenticated to access it. Please log in. - silently ignoring the lookup for the file config.json in google/gemma-2-9b.
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/save_and_load.py:246: UserWarning: Could not find a config file in google/gemma-2-9b - will assume that the vocabulary was not modified.
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/other.py:716: UserWarning: Unable to fetch remote file due to the following error 401 Client Error. (Request ID: Root=1-6760d8cf-4907686414444e936de5c27c;30cbdc69-4ac9-41fe-8ba0-2f4c453665c5)
#
# Cannot access gated repo for url https://huggingface.co/google/gemma-2-9b/resolve/main/config.json.
# Access to model google/gemma-2-9b is restricted. You must have access to it and be authenticated to access it. Please log in. - silently ignoring the lookup for the file config.json in google/gemma-2-9b.
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/save_and_load.py:246: UserWarning: Could not find a config file in google/gemma-2-9b - will assume that the vocabulary was not modified.
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/other.py:716: UserWarning: Unable to fetch remote file due to the following error 401 Client Error. (Request ID: Root=1-6760dd61-1732d4092d4e595a7d22c2d4;cdb026c8-d067-46d5-a524-7559b845c567)
#
# Cannot access gated repo for url https://huggingface.co/google/gemma-2-9b/resolve/main/config.json.
# Access to model google/gemma-2-9b is restricted. You must have access to it and be authenticated to access it. Please log in. - silently ignoring the lookup for the file config.json in google/gemma-2-9b.
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/save_and_load.py:246: UserWarning: Could not find a config file in google/gemma-2-9b - will assume that the vocabulary was not modified.
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/other.py:716: UserWarning: Unable to fetch remote file due to the following error 401 Client Error. (Request ID: Root=1-6760e1ed-3db54e240e821c1b191b9b41;028e84cb-8e7a-4deb-b61e-fbc6679626e5)
#
# Cannot access gated repo for url https://huggingface.co/google/gemma-2-9b/resolve/main/config.json.
# Access to model google/gemma-2-9b is restricted. You must have access to it and be authenticated to access it. Please log in. - silently ignoring the lookup for the file config.json in google/gemma-2-9b.
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/save_and_load.py:246: UserWarning: Could not find a config file in google/gemma-2-9b - will assume that the vocabulary was not modified.
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/other.py:716: UserWarning: Unable to fetch remote file due to the following error 401 Client Error. (Request ID: Root=1-6760e683-75f659bb4507b06432aa2762;88c8c869-8a43-4174-afd7-f3355f4eb49c)
#
# Cannot access gated repo for url https://huggingface.co/google/gemma-2-9b/resolve/main/config.json.
# Access to model google/gemma-2-9b is restricted. You must have access to it and be authenticated to access it. Please log in. - silently ignoring the lookup for the file config.json in google/gemma-2-9b.
#   warnings.warn(
# ...
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/other.py:716: UserWarning: Unable to fetch remote file due to the following error 401 Client Error. (Request ID: Root=1-676134b0-6dd885467fb0958e58db28fa;e2377063-2cc9-4d80-a93f-3efa450f065a)
#
# Cannot access gated repo for url https://huggingface.co/google/gemma-2-9b/resolve/main/config.json.
# Access to model google/gemma-2-9b is restricted. You must have access to it and be authenticated to access it. Please log in. - silently ignoring the lookup for the file config.json in google/gemma-2-9b.
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/save_and_load.py:246: UserWarning: Could not find a config file in google/gemma-2-9b - will assume that the vocabulary was not modified.
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/other.py:716: UserWarning: Unable to fetch remote file due to the following error 401 Client Error. (Request ID: Root=1-67613940-019326061b5e16324cde3cf7;a8aab258-9d4b-410c-8ff6-9e78130401cd)
#
# Cannot access gated repo for url https://huggingface.co/google/gemma-2-9b/resolve/main/config.json.
# Access to model google/gemma-2-9b is restricted. You must have access to it and be authenticated to access it. Please log in. - silently ignoring the lookup for the file config.json in google/gemma-2-9b.
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/save_and_load.py:246: UserWarning: Could not find a config file in google/gemma-2-9b - will assume that the vocabulary was not modified.
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/other.py:716: UserWarning: Unable to fetch remote file due to the following error 401 Client Error. (Request ID: Root=1-67613dd3-3df1a4fd3e624d1b297dc3f5;ad69cfde-b873-41cb-8fdd-978304b803f1)
#
# Cannot access gated repo for url https://huggingface.co/google/gemma-2-9b/resolve/main/config.json.
# Access to model google/gemma-2-9b is restricted. You must have access to it and be authenticated to access it. Please log in. - silently ignoring the lookup for the file config.json in google/gemma-2-9b.
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/save_and_load.py:246: UserWarning: Could not find a config file in google/gemma-2-9b - will assume that the vocabulary was not modified.
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/other.py:716: UserWarning: Unable to fetch remote file due to the following error 401 Client Error. (Request ID: Root=1-6761425d-4a7a4d3a0039fdb04f674050;4d757149-cfdd-430e-98a3-f984e5d59118)
#
# Cannot access gated repo for url https://huggingface.co/google/gemma-2-9b/resolve/main/config.json.
# Access to model google/gemma-2-9b is restricted. You must have access to it and be authenticated to access it. Please log in. - silently ignoring the lookup for the file config.json in google/gemma-2-9b.
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/save_and_load.py:246: UserWarning: Could not find a config file in google/gemma-2-9b - will assume that the vocabulary was not modified.
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/other.py:716: UserWarning: Unable to fetch remote file due to the following error 401 Client Error. (Request ID: Root=1-676146f1-693fc855191b000a4fa83a17;c4af7ed9-b00b-4aa4-bfda-bc3b0a062088)
#
# Cannot access gated repo for url https://huggingface.co/google/gemma-2-9b/resolve/main/config.json.
# Access to model google/gemma-2-9b is restricted. You must have access to it and be authenticated to access it. Please log in. - silently ignoring the lookup for the file config.json in google/gemma-2-9b.
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/save_and_load.py:246: UserWarning: Could not find a config file in google/gemma-2-9b - will assume that the vocabulary was not modified.
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/other.py:716: UserWarning: Unable to fetch remote file due to the following error 401 Client Error. (Request ID: Root=1-67614b83-643ded9e1194b40f29c01f29;f3165d1c-e911-4957-a50c-d841aecc9320)
#
# Cannot access gated repo for url https://huggingface.co/google/gemma-2-9b/resolve/main/config.json.
# Access to model google/gemma-2-9b is restricted. You must have access to it and be authenticated to access it. Please log in. - silently ignoring the lookup for the file config.json in google/gemma-2-9b.
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/save_and_load.py:246: UserWarning: Could not find a config file in google/gemma-2-9b - will assume that the vocabulary was not modified.
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/other.py:716: UserWarning: Unable to fetch remote file due to the following error 401 Client Error. (Request ID: Root=1-67615015-21b5fd525cf9359511d641c2;cb58cbee-264e-4cd2-8ea1-00b572d246f4)
#
# Cannot access gated repo for url https://huggingface.co/google/gemma-2-9b/resolve/main/config.json.
# Access to model google/gemma-2-9b is restricted. You must have access to it and be authenticated to access it. Please log in. - silently ignoring the lookup for the file config.json in google/gemma-2-9b.
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/save_and_load.py:246: UserWarning: Could not find a config file in google/gemma-2-9b - will assume that the vocabulary was not modified.
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/other.py:716: UserWarning: Unable to fetch remote file due to the following error 401 Client Error. (Request ID: Root=1-676154ad-46d7893f0f452bca2d9aa4c0;2f0cfa28-7050-4fd2-bd70-25b717074496)
#
# Cannot access gated repo for url https://huggingface.co/google/gemma-2-9b/resolve/main/config.json.
# Access to model google/gemma-2-9b is restricted. You must have access to it and be authenticated to access it. Please log in. - silently ignoring the lookup for the file config.json in google/gemma-2-9b.
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/save_and_load.py:246: UserWarning: Could not find a config file in google/gemma-2-9b - will assume that the vocabulary was not modified.
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/other.py:716: UserWarning: Unable to fetch remote file due to the following error 401 Client Error. (Request ID: Root=1-67615943-2758a4d7300a17125a215016;6eeb7204-94ec-4e88-9ccf-e07ff6ade3bd)
#
# Cannot access gated repo for url https://huggingface.co/google/gemma-2-9b/resolve/main/config.json.
# Access to model google/gemma-2-9b is restricted. You must have access to it and be authenticated to access it. Please log in. - silently ignoring the lookup for the file config.json in google/gemma-2-9b.
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/save_and_load.py:246: UserWarning: Could not find a config file in google/gemma-2-9b - will assume that the vocabulary was not modified.
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/other.py:716: UserWarning: Unable to fetch remote file due to the following error 401 Client Error. (Request ID: Root=1-67615dd9-72e19e131ab0e4d024f1a6d2;6b22f7b1-0e86-4f4a-9cb7-5a4740e24d56)
#
# Cannot access gated repo for url https://huggingface.co/google/gemma-2-9b/resolve/main/config.json.
# Access to model google/gemma-2-9b is restricted. You must have access to it and be authenticated to access it. Please log in. - silently ignoring the lookup for the file config.json in google/gemma-2-9b.
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/save_and_load.py:246: UserWarning: Could not find a config file in google/gemma-2-9b - will assume that the vocabulary was not modified.
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/other.py:716: UserWarning: Unable to fetch remote file due to the following error 401 Client Error. (Request ID: Root=1-67616278-6679d9cf01d2e1774122a2a1;e03cc160-e544-4f47-935c-8a7e2c65bd3d)
#
# Cannot access gated repo for url https://huggingface.co/google/gemma-2-9b/resolve/main/config.json.
# Access to model google/gemma-2-9b is restricted. You must have access to it and be authenticated to access it. Please log in. - silently ignoring the lookup for the file config.json in google/gemma-2-9b.
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/save_and_load.py:246: UserWarning: Could not find a config file in google/gemma-2-9b - will assume that the vocabulary was not modified.
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/other.py:716: UserWarning: Unable to fetch remote file due to the following error 401 Client Error. (Request ID: Root=1-6761671a-393243b323955c0f55ead5a7;080509c4-3224-4343-9c9f-b0b38b52f840)
#
# Cannot access gated repo for url https://huggingface.co/google/gemma-2-9b/resolve/main/config.json.
# Access to model google/gemma-2-9b is restricted. You must have access to it and be authenticated to access it. Please log in. - silently ignoring the lookup for the file config.json in google/gemma-2-9b.
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/save_and_load.py:246: UserWarning: Could not find a config file in google/gemma-2-9b - will assume that the vocabulary was not modified.
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/other.py:716: UserWarning: Unable to fetch remote file due to the following error 401 Client Error. (Request ID: Root=1-67616bbc-715f99dc324ebc063389a0b4;ae918db1-8cb6-4410-a65d-4515cf00125e)
#
# Cannot access gated repo for url https://huggingface.co/google/gemma-2-9b/resolve/main/config.json.
# Access to model google/gemma-2-9b is restricted. You must have access to it and be authenticated to access it. Please log in. - silently ignoring the lookup for the file config.json in google/gemma-2-9b.
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/save_and_load.py:246: UserWarning: Could not find a config file in google/gemma-2-9b - will assume that the vocabulary was not modified.
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/other.py:716: UserWarning: Unable to fetch remote file due to the following error 401 Client Error. (Request ID: Root=1-6761705d-43863a7b3398ee637cc4b225;c00b2044-be82-4a3c-8d54-c365fea4738d)
#
# Cannot access gated repo for url https://huggingface.co/google/gemma-2-9b/resolve/main/config.json.
# Access to model google/gemma-2-9b is restricted. You must have access to it and be authenticated to access it. Please log in. - silently ignoring the lookup for the file config.json in google/gemma-2-9b.
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/save_and_load.py:246: UserWarning: Could not find a config file in google/gemma-2-9b - will assume that the vocabulary was not modified.
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/other.py:716: UserWarning: Unable to fetch remote file due to the following error (ReadTimeoutError("HTTPSConnectionPool(host='huggingface.co', port=443): Read timed out. (read timeout=10)"), '(Request ID: aa3dabe5-5040-490d-800e-a525ac1a83c4)') - silently ignoring the lookup for the file config.json in google/gemma-2-9b.
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/save_and_load.py:246: UserWarning: Could not find a config file in google/gemma-2-9b - will assume that the vocabulary was not modified.
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/other.py:716: UserWarning: Unable to fetch remote file due to the following error 401 Client Error. (Request ID: Root=1-676179a8-2188cb8a373da239114a5358;b55e4223-36b1-4c77-ba6a-265a0bffce01)
#
# Cannot access gated repo for url https://huggingface.co/google/gemma-2-9b/resolve/main/config.json.
# Access to model google/gemma-2-9b is restricted. You must have access to it and be authenticated to access it. Please log in. - silently ignoring the lookup for the file config.json in google/gemma-2-9b.
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/save_and_load.py:246: UserWarning: Could not find a config file in google/gemma-2-9b - will assume that the vocabulary was not modified.
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/other.py:716: UserWarning: Unable to fetch remote file due to the following error 401 Client Error. (Request ID: Root=1-67617e43-518dcfa25a73743e08a513c8;b4b822f5-440d-46a0-93ac-569262e95fae)
#
# Cannot access gated repo for url https://huggingface.co/google/gemma-2-9b/resolve/main/config.json.
# Access to model google/gemma-2-9b is restricted. You must have access to it and be authenticated to access it. Please log in. - silently ignoring the lookup for the file config.json in google/gemma-2-9b.
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/save_and_load.py:246: UserWarning: Could not find a config file in google/gemma-2-9b - will assume that the vocabulary was not modified.
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/other.py:716: UserWarning: Unable to fetch remote file due to the following error 401 Client Error. (Request ID: Root=1-676182d1-39fb3e324307bf5e26248b66;23f8f08d-6877-4dc7-b7ce-f6d2694ee083)
#
# Cannot access gated repo for url https://huggingface.co/google/gemma-2-9b/resolve/main/config.json.
# Access to model google/gemma-2-9b is restricted. You must have access to it and be authenticated to access it. Please log in. - silently ignoring the lookup for the file config.json in google/gemma-2-9b.
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/save_and_load.py:246: UserWarning: Could not find a config file in google/gemma-2-9b - will assume that the vocabulary was not modified.
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/other.py:716: UserWarning: Unable to fetch remote file due to the following error 401 Client Error. (Request ID: Root=1-67618768-5fbab027785718ff750eaaf2;d87522e5-987c-49c9-a3e2-a459eacca977)
#
# Cannot access gated repo for url https://huggingface.co/google/gemma-2-9b/resolve/main/config.json.
# Access to model google/gemma-2-9b is restricted. You must have access to it and be authenticated to access it. Please log in. - silently ignoring the lookup for the file config.json in google/gemma-2-9b.
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/save_and_load.py:246: UserWarning: Could not find a config file in google/gemma-2-9b - will assume that the vocabulary was not modified.
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/other.py:716: UserWarning: Unable to fetch remote file due to the following error 401 Client Error. (Request ID: Root=1-67618c02-34feb4b37d9f9e5973deab49;01620850-da89-47fa-bd56-c369fd63484a)
#
# Cannot access gated repo for url https://huggingface.co/google/gemma-2-9b/resolve/main/config.json.
# Access to model google/gemma-2-9b is restricted. You must have access to it and be authenticated to access it. Please log in. - silently ignoring the lookup for the file config.json in google/gemma-2-9b.
#   warnings.warn(
# /root/miniconda3/envs/Gemma/lib/python3.12/site-packages/peft/utils/save_and_load.py:246: UserWarning: Could not find a config file in google/gemma-2-9b - will assume that the vocabulary was not modified.
#   warnings.warn(
